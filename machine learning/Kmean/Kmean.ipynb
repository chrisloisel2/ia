# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %% [markdown]
# ### Affichage de iris avec seaborn

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
plt.title('Iris Dataset')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(iris.data[:, 2], iris.data[:, 3], c='black', s=100)
plt.show()

# %%
data = pd.DataFrame(iris.data, columns=iris.feature_names)
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Création d'un graphique de dispersion de iris en utilisant seaborn

# %%
import seaborn as sns

sns.scatterplot(data=data, x='sepal length (cm)', y='sepal width (cm)')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

kmeans.fit(data)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
data['cluster'] = kmeans.labels_

# %%
print("centroids: ", kmeans.cluster_centers_)
print("inertia: ", kmeans.inertia_)
# Out:
# centroids:  [[6.29183673 2.8877551  4.92653061 1.7122449 ]
#  [5.006      3.428      1.462      0.246     ]
#  [5.53214286 2.63571429 3.96071429 1.22857143]
#  [7.08695652 3.12608696 6.01304348 2.14347826]]
# inertia:  57.35088021295475

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['sepal length (cm)'], data['sepal width (cm)'], c=data['cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x')
plt.title('Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()
