# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# install seaborn
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Importer mon fichier de données
# - analyse des données avec seaborn

# %%
df = pd.read_csv('dataset.csv')

# %%
sns.pairplot(df, x_vars=['x'], y_vars=['y'], height=5, aspect=0.7, kind='reg')

# %%
plt.scatter(df['x'], df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ## Diviser le jeu de données en deux parties
# - 80% pour l'entraînement
# - 20% pour le test
#
# on utilise la fonction train_test_split de sklearn

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['x']], df['y'], test_size=0.2, random_state=0)

# %% [markdown]
# ## Créer un modèle de régression linéaire
# - On utilise la fonction LinearRegression de sklearn
# - On entraîne le modèle sur les données d'entraînement

# %%
# Cree un model de regression lineaire
model = LinearRegression()


# entrainer le model avec ma data (x_train, y_train)
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## évaluer le modèle
# - On utilise la fonction score de sklearn pour évaluer le modèle sur les données de test
# - On affiche le score
# - on affiche les resultats de la prédiction

# %%
# predire les valeurs de y pour x_test
y_pred = model.predict(x_test)

# Comparer les valeurs predites avec les valeurs reelles
mse = mean_squared_error(y_test, y_pred)


# Afficher le Mean Squared Error
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 4.7855393223716

# %% [markdown]
# # Affichage de mon resultat

# %%
plt.scatter(x_test, y_test, color='blue', label='True values')
plt.plot(x_test, y_pred, color='red', label='Predicted values')
plt.xlabel('x')
plt.ylabel('y')
plt.title('True values vs Predicted values')
plt.legend()
plt.show()

# %%
new_y = model.predict([[10050]])
